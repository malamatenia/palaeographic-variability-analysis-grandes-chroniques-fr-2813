# %% [markdown]
# # Use this for filtering entire directory

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.ndimage import binary_dilation, label, gaussian_filter
from PIL import Image, ImageDraw, ImageOps
from scipy.ndimage import binary_dilation, label, gaussian_filter
from utils.utils_prototypes import crop_it, filter_it, flag_it

# %%
# Example usage
crop_it(
    input_dir="../results/prototypes/original",
    output_dir="../results/prototypes/cropped",
    crop_top=7, crop_bottom=7, crop_left=7, crop_right=7
)

# %% [markdown]
# ## Filter the prototypes

# %%
filter_it(
    input_parent_folder="../results/prototypes/cropped",
    output_parent_folder="../results/prototypes/test",
    baseline_folder="../results/prototypes/cropped/baseline/",
    index_range=range(26, 50),
    threshold_ratio=0.71
)
# Out:
# Skipping 'btv1b84472995_f761': output already exists.
# Skipping 'btv1b84472995_f538': output already exists.
# Skipping 'btv1b84472995_f910': output already exists.
# Skipping 'btv1b84472995_f808': output already exists.
# Skipping 'btv1b84472995_f716b': output already exists.
# Skipping 'btv1b84472995_f96': output already exists.
# Skipping 'btv1b84472995_f725': output already exists.
# Skipping 'btv1b84472995_f141': output already exists.
# Skipping 'btv1b84472995_f975': output already exists.
# Skipping 'btv1b84472995_f173': output already exists.
# Skipping 'btv1b84472995_f977': output already exists.
# Skipping 'btv1b84472995_f945': output already exists.
# Skipping 'btv1b84472995_f781': output already exists.
# Skipping 'btv1b84472995_f879': output already exists.
# Skipping 'btv1b84472995_f984': output already exists.
# Skipping 'btv1b84472995_f979b': output already exists.
# Skipping 'btv1b84472995_f716': output already exists.
# ...

# %%
df = flag_it(
    input_parent_folder="../results/prototypes/cropped/",
    output_parent_folder="../results/prototypes/borders_test/",
    baseline_folder="../results/prototypes/cropped/baseline/",
    index_range=range(26, 50),
    default_threshold_ratio=0.71,
    sup_threshold_ratio=0.67,
    orange_threshold=(6, 16), red_threshold=30
)

# View difference data
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = flag_it(
#       2     input_parent_folder="../results/prototypes/cropped/",
#       3     output_parent_folder="../results/prototypes/borders_test/",
#       4     baseline_folder="../results/prototypes/cropped/baseline/",
#       5     index_range=range(26, 50),
#       6     default_threshold_ratio=0.71,
#       7     sup_threshold_ratio=0.67,
#       8     orange_threshold=(6, 16), red_threshold=30
#       9 )
#      11 # View difference data
#      12 print(df)
#
# File ~/palaeographic-variability-analysis-grandes-chroniques-fr-2813/scripts/utils/utils_prototypes.py:222, in flag_it(input_parent_folder, output_parent_folder, baseline_folder, index_range, default_threshold_ratio, sup_threshold_ratio, orange_threshold, red_threshold)
#     219     ax.axis('off')
# ...
